# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200, n_features=2, centers = 3, cluster_std = 2.5)
data
# Out:
# (array([[ 4.36059892e+00, -6.88464133e+00],
#         [ 7.36702531e+00, -4.52224643e+00],
#         [ 8.97095740e+00, -3.80323828e+00],
#         [ 7.38068107e+00, -5.17074989e+00],
#         [-6.95792152e+00,  4.22175892e+00],
#         [-5.34312417e+00,  5.24530550e+00],
#         [ 5.90502451e+00, -2.11545839e+00],
#         [ 6.27039871e+00,  8.28163541e-01],
#         [ 9.31268412e+00, -2.95818163e+00],
#         [-9.00860205e+00,  4.17919848e-01],
#         [-1.04678865e+01,  3.92057649e+00],
#         [-4.59397357e+00,  3.85530810e+00],
#         [-6.32643512e+00,  2.60915361e+00],
#         [-1.18035905e+01, -4.18968374e+00],
#         [ 1.05230157e+01, -2.14236055e+00],
#         [ 7.37985584e+00, -1.58201644e+00],
#         [ 1.08051718e+01, -4.97303503e+00],
#         [ 5.88579341e+00, -2.91469277e+00],
#         [-9.07570579e+00, -9.12658851e+00],
#         [-8.85579138e+00, -1.14959093e+01],
#         [ 7.75424960e+00,  1.22997322e+00],
# ...

# %%
plt.scatter(data[0][:, 0], data[0][:,1], c = data[1], cmap = 'rainbow')

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=3)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(n_clusters=3)

# %%
kmeans.cluster_centers_
# Out:
# array([[-6.78769721, -4.87191265],
#        [ 8.24563154, -2.66206951],
#        [-6.36461817,  3.12982038]])

# %%
kmeans.labels_
# Out:
# array([1, 1, 1, 1, 2, 2, 1, 1, 1, 2, 2, 2, 2, 0, 1, 1, 1, 1, 0, 0, 1, 2,
#        0, 2, 0, 2, 1, 2, 1, 1, 2, 0, 1, 2, 1, 2, 1, 2, 0, 2, 2, 2, 2, 2,
#        1, 0, 2, 0, 0, 0, 1, 0, 0, 0, 0, 1, 2, 2, 2, 0, 1, 0, 2, 0, 0, 2,
#        1, 2, 1, 1, 1, 1, 0, 1, 2, 1, 1, 2, 2, 2, 0, 0, 2, 1, 1, 0, 2, 0,
#        1, 2, 1, 0, 1, 2, 0, 2, 2, 1, 0, 0, 0, 1, 0, 1, 1, 2, 1, 2, 2, 1,
#        2, 0, 2, 0, 0, 1, 2, 1, 1, 2, 0, 0, 2, 2, 2, 0, 1, 2, 0, 0, 0, 0,
#        1, 0, 1, 1, 2, 1, 0, 0, 0, 0, 2, 1, 1, 2, 2, 0, 2, 0, 1, 1, 0, 2,
#        2, 2, 1, 0, 0, 1, 0, 1, 0, 2, 2, 1, 2, 1, 1, 1, 0, 1, 2, 1, 2, 0,
#        2, 0, 0, 0, 2, 2, 2, 1, 0, 0, 2, 1, 0, 0, 1, 2, 2, 1, 2, 1, 0, 0,
#        2, 2])

# %%
f, (ax1, ax2) = plt.subplots(1,2, sharey = True, figsize = (10, 6))
ax1.set_title('k_Means')
ax1.scatter(data[0][:,0], data[0][:,1], c = kmeans.labels_, cmap = 'rainbow')
ax2.set_title('Original')
ax2.scatter(data[0][:,0], data[0][:,1], c = data[1], cmap = 'rainbow')


# plt.figure(figsize=(14,6))
# plt.subplot(1,2,1)
# plt.scatter(data[0][:,0],data[0][:,1],c=data[1], cmap=matplotlib.cm.autumn)
# plt.subplot(1,2,2)
# plt.scatter(data[0][:,0],data[0][:,1],c=pred, cmap=matplotlib.cm.autumn)
